# %%
#My first test socket program
import socket
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect(("www.pph.hu", 80))
s.send(b"GET / HTTP/1.1\r\nHost: www.pph.hu\r\n\r\n")
data = s.recv(1024)
print(data)
s.close()
# Out:
# b'HTTP/1.1 301 Moved Permanently\r\nDate: Thu, 30 Oct 2025 19:36:21 GMT\r\nServer: Apache/2.4.56 (Debian)\r\nUpgrade: h2,h2c\r\nConnection: Upgrade\r\nSet-Cookie: ATD202304=lj69q0sp29tqkip3lgdredun6m; path=/\r\nExpires: Thu, 19 Nov 1981 08:52:00 GMT\r\nCache-Control: no-store, no-cache, must-revalidate\r\nPragma: no-cache\r\nLocation: /hu/\r\nContent-Length: 0\r\nContent-Type: text/html; charset=UTF-8\r\n\r\n'

# %%
#create script for ip address and port number
import socket
import sys

try:
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.connect((sys.argv[1], int(sys.argv[2])))
    print(f"Connected to {sys.argv[1]} on port {sys.argv[2]}")
    s.close()
except Exception as e:
    print(f"Failed to connect: {e}")

# %%
#server side socket program
import socket
host = 'localhost'
port = 8080

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((host, port))
s.listen(1)
print("The server is running and waiting for connections...")
comm, address =s.accept()
message = 'Hello, World!' + "\r\n"
comm.send(message.encode('utf-8'))
comm.close()

# %%
#client side socket program
import socket
host = 'localhost'
port = 8080
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect((host, port))
message = s.recv(1024)
while message:
    print("Message":message.decode('utf-8'))
    message = s.recv(1024)
s.close()

# %%
#File transfer using sockets
import socket
host = 'localhost'
port = 8080

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((host, port))
s.listen(1)
print("The server is running and waiting for connections...")
comm, address =s.accept()
try:
    fileName = comm.recv(1024).decode('utf-8')
    file = open(fileName, 'rb')
    readFile = file.read(1024)
    comm.send(readFile)
    file.close()
except FileNotFoundError:
    comm.send(b'File not found')
    

comm.close()

# %%
#client file transfer
import socket
host = 'localhost'
port = 8080
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect((host, port))
fileName = test.txt
s.send(fileName.encode('utf-8'))
readFile = s.recv(1024)
comm.send(readFile)
file.close()

s.close()
