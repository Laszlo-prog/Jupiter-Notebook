# %%
#Source inspired: https://www.youtube.com/watch?v=e4fwY9ZsxPw&t=2901s
name = input("Enter your name: ")
house = input("Enter your house: ")
print(f"Hello, {name} of {house}!")

# %%
name = "Laszlo"
house = "Hufflepuff"
print(f"Hello, {name} of {house}!")
# --- IGNORE ---
# Out:
# Hello, Laszlo of Hufflepuff!

# %%
def main():
    name = "Potter"
    house = "Gryffindor"
    print(f"Hello, {name} of {house}!")

def get_name():
    return "Potter"

# %%
def get_house():
    return "Gryffindor"

get_house()
# Out:
# 'Gryffindor'

# %%
def get_student():
    name = "Harry", "Padma"
    house = "Gryffindor", "Ravenclaw"
    patronus = "Stag", "Otter"
    return name, house

get_student()
# Out:
# ('Harry', 'Gryffindor')

# %%
def main():
    student = get_student()
    print(f"Hello, {student[0]} of {student[1]}")
    

if __name__ == "__main__":
    main()
# Out:
# Hello, Harry of Gryffindor

# %%
#create dictionary now 
def get_student():
    student = {
        "name": "Harry",
        "house": "Gryffindor",
        "patronus": "Stag"
    }
    return student

get_student()
# Out:
# {'name': 'Harry', 'house': 'Gryffindor'}

# %%
#Calsses and Objects CS50P lecture 8 Object-oriented programming
class Student:
    def __init__(self, name, house):
        
        self.name = name
        self.house = house

def get_student():

    return Student("Harry", "Gryffindor", "Stag")

student = get_student()
print(f"Hello, {student.name} of {student.house} and your patronus is {student.patronus}")

if __name__ == "__main__":
    get_student()
# Out:
# Hello, Harry of Gryffindor

# %%
#create instance methods
class Student:
    def __init__(self, name, house, patronus):
        if not name:
            raise ValueError("Missing name")
        if not house:
            raise ValueError("Missing house")
        self.name = name
        self.house = house
        self.patronus = patronus

    def greeting(self):
        return f"Hello, {self.name} of {self.house} and your patronus is {self.patronus}"    
    
def get_student():
    return Student("Harry", "Gryffindor", "Stag")

student = get_student()
print(student.greeting())

if __name__ == "__main__":
    get_student()
# Out:
# Hello, Harry of Gryffindor

# %%
#create instance methods
class Student:
    def __init__(self, name, house, patronus):
        if not name:
            raise ValueError("Missing name")
        if not house:
            raise ValueError("Missing house")
        if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid house")
        self.name = name
        self.house = house
        self.patronus = patronus


    def greeting(self):
        return f"Hello, {self.name} of {self.house} and your patronus is {self.patronus}"    
    
def get_student():
    return Student("Harry", "Gryffindor", "Stag")

student = get_student()
print(student.greeting())

if __name__ == "__main__":
    get_student()
# Out:
# Hello, Harry of Gryffindor

# %%
class Student:
    def __init__(self, name, house, patronus):
        if not name:
            raise ValueError("Missing name")
        if not house:
            raise ValueError("Missing house")
        if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid house")
        self.name = name
        self.house = house
        self.patronus = patronus

    def __str__(self):
        return f"{self.name} from {self.house} and your patronus is {self.patronus}"
    @property
    def name(self):
        return self.name
    @name.setter
    def name(self, name):
        if not name:
            raise ValueError("Missing name")
        self.name = name
    #Getter
    def house(self):
        return self.house
    #Setter
    def house(self, house):
            if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
                raise ValueError("Invalid house")
            self.house = house

    def charm(self):
        match self.patronus:
            case "Stag":
                return "🐴"
            case "Otter":
                return "🦦"
            case "Jack Russell Terrier":
                return "🐕"
            case "Phoenix":
                return "🦜"
            case _:
                return "🪄"

    def greeting(self):
        return f"Hello, {self.name} of {self.house} and your patronus is {self.patronus}"    
    
def get_student():
    return Student("Harry", "Gryffindor" , "Stag")

student = get_student()
print(student.greeting())
print(student.charm())

if __name__ == "__main__":
    get_student()
# Out:
# Hello, Harry of Gryffindor and your patronus is Stag

# %%
#Calsses and Objects CS50P lecture 8 Object-oriented programming
class Student:
    def __init__(self, name, house, patronus):
        
        self.name = name
        self.house = house
        self.patronus = patronus

def get_student():


    return Student("Harry", "Gryffindor" , "Stag")

student = get_student()
print(f"Hello, {student.name} of {student.house} and your patronus is {student.patronus}")

if __name__ == "__main__":
    get_student()
# Out:
# Hello, Harry of Gryffindor and your patronus is Stag
