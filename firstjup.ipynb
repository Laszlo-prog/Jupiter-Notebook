# %%
name = 'Laszlo'
age = 34
job = 'Electrician'

print(f"My name is {name}, and {age}, years old")

data = [ name, age, job]
# Out:
# My name is Laszlo, and 34, years old

# %%
data = [name, age, job]
print(f"All about me {data}, for you")
# Out:
# All about me ['Laszlo', 34, 'Electrician'], for you

# %%
mylist = [1,2,3,4,5,6]

for num in mylist:
    print('Hello')
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
for num in mylist:
    if num % 2 == 0:
        print(num)
    else:
        print(f"Add Number: {num}")
# Out:
# Add Number: 1
# 2
# Add Number: 3
# 4
# Add Number: 5
# 6

# %%
list_sun = 0

for num in mylist:
    list_sun = list_sun + num
    print(list_sun * 246)
# Out:
# 246
# 738
# 1476
# 2460
# 3690
# 5166

# %%
mystring = 'Hello Friend'
for letter in mystring:
    print(letter)
# Out:
# H
# e
# l
# l
# o
#
# F
# r
# i
# e
# n
# d

# %%
tuple = (1,2,3)
for item in tuple:
    print(item)
# Out:
# 1
# 2
# 3

# %%
# Another programming example fo

for number in range(3):
    print("Sending messages!!", number + 1, (number + 1))
# Out:
# Sending messages!! 1 1
# Sending messages!! 2 2
# Sending messages!! 3 3

# %%
successful = True
for number in range(5):
    print("Attention")
    if successful:
        print("Successful")
        break
else:
    print("attention 3 times and failed")
# Out:
# Attention
# Successful

# %%
listam = [(1,2),(3,4),(5,6)]
len(listam)

for item in listam:
    print(item)
# Out:
# (1, 2)
# (3, 4)
# (5, 6)

# %%
#while loop section
x = 0
while x < 5:
    print(f"The current value of x is {x}")
    x = x + 1
# Out:
# The current value of x is 0
# The current value of x is 1
# The current value of x is 2
# The current value of x is 3
# The current value of x is 4

# %%
mytext = "Hallo"
for letter in mytext:
    if letter == 'a':
        continue
        
    print(letter)
# Out:
# H
# l
# l
# o

# %%
x = 6
while x < 6:
    if x == 2:
        continue
    print(f"the current of x is {x}")
    break

# %%
count = 1
while count <= 5:
    count += 1
    print("Messages")
# Out:
# Messages
# Messages
# Messages
# Messages
# Messages

# %%
for count in range(1, 6):
    print("Messages!!!")
# Out:
# Messages!!!
# Messages!!!
# Messages!!!
# Messages!!!
# Messages!!!

# %%
#Operation in python

miolist = [1,2,3]

for num in range(3,10):
    print(num)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# Comprehension in python
mylett = 'Arnold'

mywatt = []
for letter in mylett:
    mywatt.append(letter)
    print(mylett)
# Out:
# Arnold
# Arnold
# Arnold
# Arnold
# Arnold
# Arnold

# %%
mywatt = [x**2 for x in range(0, 11)]

print(mywatt)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
szami = [1,2,3,4,5]
szami_squared = [ ]
for i in szami:
    square = i**2
    szami_squared.append(square)

print(szami_squared)
# Out:
# [1, 4, 9, 16, 25]

# %%
szami_squared = [i**2 for i in szami]
print(szami_squared)
# Out:
# [1, 4, 9, 16, 25]

# %%
#List comprehensions
# list expres
#[expr. for val in collection]
#[for val in collection if <test>]
#[for val in collection if<test1> and <test2>]
#[expr. for val1 in  more collection val2]

negyzet = [ ]
for i in range(1, 100):
    negyzet.append(i**2)
    print(negyzet)
# Out:
# [1]
# [1, 4]
# [1, 4, 9]
# [1, 4, 9, 16]
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25, 36]
# [1, 4, 9, 16, 25, 36, 49]
# [1, 4, 9, 16, 25, 36, 49, 64]
# [1, 4, 9, 16, 25, 36, 49, 64, 81]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400]
# ...

# %%
movies = ["Star Wars", "Gandhi", "Casablanca", "Shawshank Redemption","ToyStory",
          "Gone with wind", "Citizen Kane", "It is wonderful Life", "Ghostbuster"]

gmovies = [ ]

for title in movies:
    if title.startswith("G"):
        gmovies.append(title)
print(gmovies)
# Out:
# ['Gandhi', 'Gone with wind', 'Ghostbuster']

# %%
filmek = [("Citizen Kane", 1942), ("Spirited Away", 2001), ("Gattaca", 1997), ("Old man", 2007)]

pre2K = [title for (title, year) in filmek if year < 2000]

print(pre2K)
# Out:
# ['Citizen Kane', 'Gattaca']

# %%
fruits = ["apple", "banana", "strawberries", "watermelon", "piesces"]
#result = []
#for fruit in fruits:
    #fruit = fruit.upper()
    #result.append(fruit)
#fruits = result
#print(fruits)

fruits = [fruit.upper() for fruit in fruits]
print(fruits)
# Out:
# ['APPLE', 'BANANA', 'STRAWBERRIES', 'WATERMELON', 'PIESCES']

# %%
negyzet2 = [i**2 for i in range(1, 101)]
print(negyzet2)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604, 9801, 10000]

# %%
level5 = [x**2 % 5 for x in range(1,101)]
print(level5)
# Out:
# [1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0, 1, 4, 4, 1, 0]

# %%
level11 =[x**2 % 11 for x in range(1,101)]
print(level11)
# Out:
# [1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1, 4, 9, 5, 3, 3, 5, 9, 4, 1, 0, 1]

# %%
import pandas as  pd
import numpy as np


data = {
    'name': ['Maria'],
    'age': [23],
    'Income': [3.500]

}

df = pd.DataFrame(data)

print(df)
print("=======================")
print(df.info)
# Out:
#     name  age  Income
# 0  Maria   23     3.5
# ...
# <bound method DataFrame.info of     name  age  Income
# 0  Maria   23     3.5>

# %%
import pandas as pd
import numpy as np
#Adat vazlat keszites.

adat = {
    'name': ['Peter', 'Janos', 'Lajos'],
    'age': [29, 31, 41],
    'department': ['Manager', 'Karbantarto', 'Gepesz'],
    'fuzetes': [75.000, 65.000, 63000],
    'experience': [5, 2, 7]
}

df = pd.DataFrame(adat)
print(df.head)
print(df.info)
# Out:
# <bound method NDFrame.head of     name  age   department  fuzetes  experience
# 0  Peter   29      Manager     75.0           5
# 1  Janos   31  Karbantarto     65.0           2
# 2  Lajos   41       Gepesz  63000.0           7>
# <bound method DataFrame.info of     name  age   department  fuzetes  experience
# 0  Peter   29      Manager     75.0           5
# 1  Janos   31  Karbantarto     65.0           2
# 2  Lajos   41       Gepesz  63000.0           7>

# %%
#method and function

x = szam = [1,2,3,4]

#szam.append(5)
x.pop()

print(x[::3])
# Out:
# [1]
